# %% [markdown]
# flow chart is a graphical representation of a process,
# it uses symbols and arrows to represent a sequence of steps
# flow charts are useful to visualize how to solve a problem and make it easily understandable

# %% [markdown]
# all are in below folder

# %% [markdown]
# C:\Users\Prakash kumar\Downloads\mydocs\Python+With+DSA+Bootcamp\Python With DSA Bootcamp\0. Foundamenal of Programming
