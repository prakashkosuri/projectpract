# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Prakash kumar\\Downloads\\projectpract\\fileoperations'

# %%
import os
os.mkdir('test_directory') # Create a new directory named 'test_directory'

# %%
import os
os.rmdir('test_directory') # Remove the directory named 'test_directory'

# %%
import os
list_items=os.listdir() # List all files and directories in the current working directory
print(list_items)
# Out:
# ['os_module.ipynb', 'readingfile.ipynb', 'sample.txt', 'sample2.txt']

# %%
#join the path
import os
file_path=os.path.join(os.getcwd(),'sample.txt')
print(file_path)
# Out:
# c:\Users\Prakash kumar\Downloads\projectpract\fileoperations\sample.txt

# %%
import os
file_path=os.path.join(os.getcwd(),'sample.txt')
path=os.path.split(file_path)
print(path)
# Out:
# ('c:\\Users\\Prakash kumar\\Downloads\\projectpract\\fileoperations', 'sample.txt')

# %%
import os
file_path=os.path.join(os.getcwd(),'sample.txt')
exists = os.path.exists(file_path)
is_file = os.path.isfile(file_path)
is_dir = os.path.isdir(file_path)
print(f"Exists: {exists}, Is File: {is_file}, Is Directory: {is_dir}")
# Out:
# Exists: True, Is File: True, Is Directory: False

# %%
import os
relative_path = 'sample3.txt'
absolute_path = os.path.abspath(relative_path)
print(f"Absolute path of '{relative_path}': {absolute_path}")
# Out:
# Absolute path of 'sample3.txt': c:\Users\Prakash kumar\Downloads\projectpract\fileoperations\sample3.txt
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
