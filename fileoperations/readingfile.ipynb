# %%
with open('sample.txt', 'r') as f:
    content = f.read()
    print(content)
# Out:
# Hello welcome to the world
# Hi from prakash
# where are you

# %%
with open('sample.txt', 'r') as f:
    a=[]
    for line in f:
        a.append(line.strip())##strip removes new line characters
print(a)
# Out:
# ['Hello welcome to the world', 'Hi from prakash', 'where are you']

# %%
with open('sample2.txt', 'w') as f:
    f.write("Hello welcome to the world\n")
    f.write("Hi from prakash\n")
    f.write("where are you\n") ##with f.write it will overwrite the existing content

# %%
with open('sample2.txt', 'a') as f:
    f.write("Hello welcome to the world of pra\n")
    f.write("Hi from pra\n")
    f.write("where are youpra\n") ##with f.write it will overwrite the existing content

# %%
lines=["hello\n","hi\n","how are you\n"]
with open('sample2.txt', 'a') as f:
    content=f.writelines(lines)

# %%
with open('sample2.txt', 'r') as f:
    content = f.readlines()
    line_count = len(content)
    word_count = sum(len(line.split()) for line in content)
    char_count = sum(len(line) for line in content)
    print(f"Lines: {line_count}, Words: {word_count}, Characters: {char_count}")
# Out:
# Lines: 6, Words: 10, Characters: 42

# %%
with open('sample2.txt', 'w+') as f:
    f.write("This is a new line\n")
    f.seek(0)  # Move the cursor to the beginning of the file
    content = f.read()
    print(content)
# Out:
# This is a new line

# %%
import os

os.path.join
