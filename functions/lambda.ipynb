# %% [markdown]
# lambda function is a small anomynous fuction defined using lambda keyword they can have any number of arguments but one expression

# %%
#syntax
lambda arguments : expression

# %%
(lambda x : x*2) (6)
# Out:
# 12

# %%
(lambda a,b : a*b) (5,6)
# Out:
# 30

# %%
a=0
print("postive")if a > 0 else print("negative")if a < 0 else print("zero")
# Out:
# zero

# %%
(lambda a : print("postive")if a > 0 else print("negative")if a < 0 else print("zero")) (0)
# Out:
# zero

# %%
(lambda a: print('even') if a%2 == 0 else print('odd') )(-2)
# Out:
# even

# %%
def addition(*n):
    return max(n)

a=addition(1,2,3,4)
print(a)


(lambda *x: max(x))(5,6,7,8)
# Out:
# 4
# 8

# %% [markdown]
# map and filter are used for collection data types or iterables

# %%
a=6
b=list(range (1,a+1))
print(list(filter(lambda x : x%2 == 0 ,b)))
# Out:
# [2, 4, 6]

# %% [markdown]
# map uses  a lazy load thechinque so we use list or tuple

# %%
print(tuple(map(lambda x : x+2 ,(6,7))))
# Out:
# (8, 9)
