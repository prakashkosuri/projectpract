# %% [markdown]
# in python modules and packages help to organize and res=use code efficiently.

# %%
pip list
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.0
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.15
# decorator               5.2.1
# executing               2.2.0
# ipykernel               6.30.0
# ipython                 9.4.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.6.3
# jupyter_core            5.8.1
# matplotlib-inline       0.1.7
# nest-asyncio            1.6.0
# packaging               25.0
# parso                   0.8.4
# pip                     25.0.1
# platformdirs            4.3.8
# prompt_toolkit          3.0.51
# psutil                  7.0.0
# pure_eval               0.2.3
# Pygments                2.19.2
# python-dateutil         2.9.0.post0
# pywin32                 311
# pyzmq                   27.0.1
# six                     1.17.0
# stack-data              0.6.3
# tornado                 6.5.1
# ...

# %%
from package import maths
print(maths.add(5,6))
# Out:
# 11
